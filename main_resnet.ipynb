# %%
import numpy as np
from PIL import Image
import cv2
import time
import pyautogui
import keyboard

import torch
from torchvision import transforms
from torchvision import models


width = 480
height = 270


    
def forward():
    keyboard.press('w')
    time.sleep(0.04)
    keyboard.release('w')

def left():
    keyboard.press('a')
    keyboard.press('w')
    time.sleep(0.04)
    keyboard.release('a')
    keyboard.release('w')

def right():
    keyboard.press('d')
    keyboard.press('w')
    time.sleep(0.04)
    keyboard.release('d')
    keyboard.release('w')
    
def brake():
    keyboard.press('s')
    time.sleep(0.04)
    keyboard.release('s')



# Load trained ResNet-50 model
model = models.resnet50(weights=None)
model.fc = torch.nn.Linear(model.fc.in_features, 4)  # 4 outputs - brake, forward, left, right
model.load_state_dict(torch.load('models/modelname.type', map_location=torch.device('cuda')))
model.eval()

for i in range(5, 0, -1):       
        print(f"Time left: {i} seconds", end='\r')
        time.sleep(1) 


# Pause to change to GTA windows
time.sleep(4)

transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((480, 270)),
    transforms.ToTensor(),
])

# Initialize the camera
cap = cv2.VideoCapture(0)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
print("running ResNet auto-pilot...................")
def main():
    
    while True:

        ret, frame = cap.read()

        if not ret:
            break

        frame = cv2.resize(frame, (width, height))
        cv2.imshow('camera', frame)
        screen_img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        screen_img = transform(screen_img).unsqueeze(0).to(device)

        with torch.no_grad():
            output = model(screen_img)
            _, predicted = torch.max(output, 1)
            prediction = predicted.item()
            
            #print probas
            # print("Probass:", output)
        
        if prediction == 0:
            brake()
            print(f"{output} brake")
        elif prediction == 1:
            forward()
            print(f"{output} forward")
        elif prediction == 2:
            left()
            print(f"{output} forward + left")
        elif prediction == 3:
            right()
            print(f"{output} forward + right")
        

        if cv2.waitKey(25) & 0xFF == ord('q'):
            cv2.destroyAllWindows()
            break
            
if __name__ == '__main__':            
    main()

# Release the camera
# cap.release()
# Out:
# running ResNet auto-pilot...................
# tensor([[-1.8793, -0.0467, -1.0650, -2.7000]], device='cuda:0') forward
# tensor([[-1.5079, -0.4241, -1.6109, -2.0167]], device='cuda:0') forward
# tensor([[-1.4756, -1.2799,  0.6121, -3.5421]], device='cuda:0') forward + left
# tensor([[-1.9404, -1.2555,  0.9049, -4.0996]], device='cuda:0') forward + left
# tensor([[-1.6699, -1.3379,  0.8339, -3.7035]], device='cuda:0') forward + left
# tensor([[-1.4493, -1.3694,  1.1708, -3.9181]], device='cuda:0') forward + left
# tensor([[-1.6686, -1.7963,  1.3447, -3.8827]], device='cuda:0') forward + left
# tensor([[-1.7467, -1.3916,  0.8370, -3.9284]], device='cuda:0') forward + left
# tensor([[-1.5100, -2.1169,  0.1777, -3.3079]], device='cuda:0') forward + left
# tensor([[-2.4662, -1.1618,  1.1235, -3.8156]], device='cuda:0') forward + left
# tensor([[-1.9950, -1.2252,  1.2930, -3.5290]], device='cuda:0') forward + left
# tensor([[-2.3767, -1.1036,  0.9590, -3.4242]], device='cuda:0') forward + left
# tensor([[-2.7983, -0.8000,  1.1956, -3.8574]], device='cuda:0') forward + left
# tensor([[-4.0039, -0.8092,  1.5799, -3.4282]], device='cuda:0') forward + left
# tensor([[-2.8033, -1.1559,  1.4362, -3.5714]], device='cuda:0') forward + left
# tensor([[-3.3579, -0.7290,  1.1769, -3.5635]], device='cuda:0') forward + left
# tensor([[-3.3728, -1.2296,  1.4534, -3.2167]], device='cuda:0') forward + left
# tensor([[-3.7124, -0.2310,  1.1911, -3.3150]], device='cuda:0') forward + left
# tensor([[-3.6524,  0.1211,  1.7079, -4.2235]], device='cuda:0') forward + left
# tensor([[-2.7395, -0.4831,  1.3349, -3.3587]], device='cuda:0') forward + left
# tensor([[-3.2805, -0.5262,  0.6342, -3.0952]], device='cuda:0') forward + left
# tensor([[-3.4936, -0.1667,  1.0094, -2.8834]], device='cuda:0') forward + left
# tensor([[-3.5249, -0.3830,  1.0312, -3.1985]], device='cuda:0') forward + left
# tensor([[-3.6445, -1.1560,  1.1880, -3.4029]], device='cuda:0') forward + left
# tensor([[-3.8526,  0.0958,  0.8702, -3.3925]], device='cuda:0') forward + left
# tensor([[-3.1741,  0.1836,  0.7199, -3.4984]], device='cuda:0') forward + left
# tensor([[-4.3272, -0.8196,  1.0859, -2.8541]], device='cuda:0') forward + left
# tensor([[-4.0682,  0.0691,  1.5193, -3.3151]], device='cuda:0') forward + left
# tensor([[-3.7913, -0.4438,  1.3887, -3.8399]], device='cuda:0') forward + left
# tensor([[-3.3949,  0.4036,  0.7803, -3.4148]], device='cuda:0') forward + left
# tensor([[-3.3059, -0.7106,  1.6898, -3.2518]], device='cuda:0') forward + left
# tensor([[-2.7416, -1.0239,  1.0125, -2.6409]], device='cuda:0') forward + left
# tensor([[-2.5986, -0.9235,  1.2825, -3.6163]], device='cuda:0') forward + left
# tensor([[-3.8354, -0.5071,  2.0127, -3.8625]], device='cuda:0') forward + left
# tensor([[-2.4917, -0.9268,  1.2190, -3.7083]], device='cuda:0') forward + left
# tensor([[-2.1534, -0.0401,  1.0496, -4.2443]], device='cuda:0') forward + left
# tensor([[-3.1835, -0.7767,  0.6348, -2.9911]], device='cuda:0') forward + left
# tensor([[-3.7075, -0.3340,  1.0165, -3.3316]], device='cuda:0') forward + left
# tensor([[-3.4886, -0.6138,  1.7315, -3.9777]], device='cuda:0') forward + left
# tensor([[-3.3330, -1.0496,  1.7119, -3.2029]], device='cuda:0') forward + left
# tensor([[-3.4275, -1.1044,  1.0977, -2.7798]], device='cuda:0') forward + left
# tensor([[-3.2352, -0.6516,  1.1278, -3.0827]], device='cuda:0') forward + left
# tensor([[-3.1189, -0.7691,  0.7857, -2.9038]], device='cuda:0') forward + left
# tensor([[-2.4754, -1.3462,  1.4728, -3.2602]], device='cuda:0') forward + left
# tensor([[-2.6033, -1.1982,  2.0975, -3.9171]], device='cuda:0') forward + left
# tensor([[-2.4529, -1.8542,  1.4932, -2.9621]], device='cuda:0') forward + left
# tensor([[-2.8470, -1.8900,  1.9791, -3.3227]], device='cuda:0') forward + left
# tensor([[-2.0686, -1.5095,  0.9955, -3.0118]], device='cuda:0') forward + left
# tensor([[-2.9775, -0.7908,  1.8595, -4.0725]], device='cuda:0') forward + left
# tensor([[-3.2356, -1.3886,  0.9640, -3.3516]], device='cuda:0') forward + left
# tensor([[-2.6222, -1.2053,  1.5008, -3.8285]], device='cuda:0') forward + left
# tensor([[-3.8542, -1.0610,  2.0619, -3.4846]], device='cuda:0') forward + left
# tensor([[-4.6085, -0.9485,  1.9597, -3.1596]], device='cuda:0') forward + left
# tensor([[-3.2472, -1.3061,  1.9938, -3.5549]], device='cuda:0') forward + left
# tensor([[-3.6004, -0.8292,  1.7295, -3.5298]], device='cuda:0') forward + left
# tensor([[-2.5358, -0.2329,  1.3304, -4.2999]], device='cuda:0') forward + left
# tensor([[-3.0972, -1.6285,  1.1379, -3.0908]], device='cuda:0') forward + left
# tensor([[-3.7949, -0.6656,  1.2000, -3.4836]], device='cuda:0') forward + left
# tensor([[-3.4598, -1.1782,  1.5782, -3.6250]], device='cuda:0') forward + left
# tensor([[-3.2350, -0.6314,  0.7703, -3.4388]], device='cuda:0') forward + left
# tensor([[-2.9505, -0.9833,  1.5492, -4.0727]], device='cuda:0') forward + left
# tensor([[-2.2621, -0.6774,  1.3532, -4.4350]], device='cuda:0') forward + left
# tensor([[-1.3400, -1.9528,  1.5326, -5.0468]], device='cuda:0') forward + left
# tensor([[-1.1837, -2.4695,  1.0213, -3.7478]], device='cuda:0') forward + left
# tensor([[-0.8188, -2.4362,  0.2407, -3.2397]], device='cuda:0') forward + left
# tensor([[-1.1990, -2.2300,  0.0871, -3.0406]], device='cuda:0') forward + left
# tensor([[-0.7479, -2.2308,  0.4412, -3.1698]], device='cuda:0') forward + left
# tensor([[-1.9315, -1.6705,  0.1451, -2.9629]], device='cuda:0') forward + left
# tensor([[-0.2178, -1.7697,  0.3206, -4.1925]], device='cuda:0') forward + left
# tensor([[ 0.5570, -2.4438, -0.0788, -4.6270]], device='cuda:0') brake
# tensor([[ 0.1382, -2.0830, -0.4538, -3.3177]], device='cuda:0') brake
# tensor([[-0.1999, -2.6262,  0.5438, -4.2573]], device='cuda:0') forward + left
# tensor([[-0.3049, -2.0186, -0.4572, -3.1222]], device='cuda:0') brake
# tensor([[-0.7342, -1.8630,  0.2456, -4.3566]], device='cuda:0') forward + left
# tensor([[ 0.2454, -2.3234,  0.0132, -3.5943]], device='cuda:0') brake
# tensor([[-0.6963, -1.8462,  0.5304, -4.3758]], device='cuda:0') forward + left
# tensor([[-0.9645, -1.5097,  0.0671, -4.4071]], device='cuda:0') forward + left
# tensor([[-0.9759, -2.8612, -0.4224, -2.2905]], device='cuda:0') forward + left
# tensor([[-0.3442, -1.9547, -0.2717, -3.0115]], device='cuda:0') forward + left
# tensor([[-1.3375, -1.6642,  0.1341, -2.9501]], device='cuda:0') forward + left
# tensor([[-1.5786, -1.7665,  0.6174, -2.5215]], device='cuda:0') forward + left
# tensor([[-1.2894, -1.5530,  0.7108, -3.1957]], device='cuda:0') forward + left
# tensor([[-1.5785, -1.0397,  1.2513, -3.6478]], device='cuda:0') forward + left
# tensor([[-1.3753, -1.4564,  0.6204, -3.4583]], device='cuda:0') forward + left
# tensor([[-2.0819, -1.3329,  0.7155, -3.8199]], device='cuda:0') forward + left
# tensor([[ 0.5438, -2.8964, -0.4237, -3.2649]], device='cuda:0') brake
# tensor([[-0.8201, -2.1540,  0.0969, -3.0229]], device='cuda:0') forward + left
# tensor([[-0.5145, -1.6739,  1.0776, -4.1727]], device='cuda:0') forward + left
# tensor([[ 0.6192, -3.4601,  0.6749, -4.5672]], device='cuda:0') forward + left
# tensor([[ 0.1769, -1.8879, -0.4779, -4.0098]], device='cuda:0') brake
# tensor([[-0.5182, -1.6260,  0.0407, -3.9514]], device='cuda:0') forward + left
# tensor([[-0.4406, -2.0358,  0.4196, -4.5490]], device='cuda:0') forward + left
# tensor([[-0.5477, -2.5660,  0.1239, -3.6617]], device='cuda:0') forward + left
# tensor([[ 0.1352, -2.1571, -0.8088, -3.7706]], device='cuda:0') brake
# tensor([[-0.1182, -2.6433, -0.9506, -2.5526]], device='cuda:0') brake
# tensor([[-0.2293, -1.8977, -0.0276, -3.6096]], device='cuda:0') forward + left
# tensor([[-0.1794, -1.9523, -0.6531, -4.3698]], device='cuda:0') brake
# tensor([[-1.0129, -2.3135, -0.5512, -3.6201]], device='cuda:0') forward + left
# tensor([[-0.5392, -1.8819,  0.4904, -4.2434]], device='cuda:0') forward + left
# tensor([[-0.6321, -2.1303,  0.2921, -3.8621]], device='cuda:0') forward + left
# tensor([[-0.0272, -2.0729,  0.3099, -3.5180]], device='cuda:0') forward + left
# tensor([[-0.5063, -2.3606,  0.3523, -3.7196]], device='cuda:0') forward + left
# tensor([[-0.6931, -1.5118,  0.1269, -3.8892]], device='cuda:0') forward + left
# tensor([[-0.9754, -1.9737,  0.8971, -3.6999]], device='cuda:0') forward + left
# tensor([[-1.1800, -2.2073,  0.6640, -3.0585]], device='cuda:0') forward + left
# tensor([[-1.2618, -1.7365,  0.6556, -3.0765]], device='cuda:0') forward + left
# tensor([[-0.5783, -1.8226,  0.4231, -2.9161]], device='cuda:0') forward + left
# tensor([[-0.3645, -1.5375,  0.4794, -3.4271]], device='cuda:0') forward + left
# tensor([[-0.4512, -2.1642,  0.6136, -3.0795]], device='cuda:0') forward + left
# tensor([[-1.4018, -0.8853,  0.4326, -3.0822]], device='cuda:0') forward + left
# tensor([[-0.6976, -2.5019,  0.3786, -2.6015]], device='cuda:0') forward + left
# tensor([[-0.9425, -1.9358,  0.6052, -2.4573]], device='cuda:0') forward + left
# tensor([[-0.2326, -1.8593,  0.2680, -3.1060]], device='cuda:0') forward + left
# tensor([[-0.6840, -2.0419,  0.7649, -3.1788]], device='cuda:0') forward + left
# tensor([[-0.7738, -1.2569,  1.0597, -3.7251]], device='cuda:0') forward + left
# tensor([[-0.8910, -1.4883,  1.1331, -3.5266]], device='cuda:0') forward + left
# tensor([[-0.3497, -0.9668,  0.3614, -3.3687]], device='cuda:0') forward + left
# tensor([[-0.4788, -1.3464,  0.4436, -3.2948]], device='cuda:0') forward + left
# tensor([[-1.3157, -0.6215,  1.1840, -3.6028]], device='cuda:0') forward + left
# tensor([[-1.1953, -1.2447,  0.1519, -3.0825]], device='cuda:0') forward + left
# tensor([[-1.0072, -0.6632,  1.1008, -3.9674]], device='cuda:0') forward + left
# tensor([[-1.4024, -0.8268,  1.1195, -4.0554]], device='cuda:0') forward + left
# tensor([[-1.6978, -0.6237,  1.4481, -4.2875]], device='cuda:0') forward + left
# tensor([[-0.8403, -1.1843,  1.2891, -3.7073]], device='cuda:0') forward + left
# tensor([[-0.8658, -1.3942,  1.2373, -4.0193]], device='cuda:0') forward + left
# tensor([[-1.4671, -1.1318,  1.5050, -3.8689]], device='cuda:0') forward + left
# tensor([[-1.0151, -1.8492,  0.9136, -3.0219]], device='cuda:0') forward + left
# tensor([[-1.4873, -1.2624,  1.1460, -3.7573]], device='cuda:0') forward + left
# tensor([[-0.9151,  2.4476, -2.0086, -3.0865]], device='cuda:0') forward
# tensor([[-0.1792,  2.5662, -3.3192, -4.2478]], device='cuda:0') forward
# tensor([[-0.0398,  1.5446, -3.5235, -2.8263]], device='cuda:0') forward
# tensor([[ 0.0820,  1.1719, -3.3644, -3.0715]], device='cuda:0') forward
# tensor([[-0.1827,  1.0431, -3.5243, -2.9001]], device='cuda:0') forward
# tensor([[-0.6972,  0.8554, -3.4315, -2.5370]], device='cuda:0') forward
# tensor([[-0.5933,  0.4592, -3.3899, -2.3205]], device='cuda:0') forward
# tensor([[-0.4300,  0.6382, -3.4766, -2.5876]], device='cuda:0') forward
# tensor([[-0.3710,  0.7237, -3.5762, -2.6012]], device='cuda:0') forward
# tensor([[-1.0861,  0.7866, -3.3214, -2.3534]], device='cuda:0') forward
# tensor([[-0.7377,  0.7503, -3.3668, -2.5785]], device='cuda:0') forward
# tensor([[-0.9012,  0.6667, -3.3868, -2.5483]], device='cuda:0') forward
# tensor([[-1.0605,  0.9201, -3.0304, -2.5900]], device='cuda:0') forward
# tensor([[-1.0158,  0.9007, -3.4447, -2.5479]], device='cuda:0') forward
# tensor([[-1.3669,  0.9289, -3.1428, -2.4139]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.1551,  0.8856, -3.1963, -2.5262]], device='cuda:0') forward
# tensor([[-1.2607,  0.9630, -3.3433, -2.5014]], device='cuda:0') forward
# tensor([[-0.6245,  0.7124, -3.5546, -2.5008]], device='cuda:0') forward
# tensor([[-0.3854,  0.7295, -3.6681, -2.8272]], device='cuda:0') forward
# tensor([[-0.5566,  0.6054, -3.6446, -2.6945]], device='cuda:0') forward
# tensor([[-0.5566,  0.6054, -3.6446, -2.6945]], device='cuda:0') forward
# tensor([[-0.5566,  0.6054, -3.6446, -2.6945]], device='cuda:0') forward
# tensor([[-0.5566,  0.6054, -3.6446, -2.6945]], device='cuda:0') forward
# tensor([[-0.5566,  0.6054, -3.6446, -2.6945]], device='cuda:0') forward
# tensor([[-0.5566,  0.6054, -3.6446, -2.6945]], device='cuda:0') forward
# tensor([[-0.5566,  0.6054, -3.6446, -2.6945]], device='cuda:0') forward
# tensor([[-0.5566,  0.6054, -3.6446, -2.6945]], device='cuda:0') forward
# tensor([[-0.5566,  0.6054, -3.6446, -2.6945]], device='cuda:0') forward
